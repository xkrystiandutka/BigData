# %%
import pandas as pd

# %%
df = pd.read_csv('passengerCount.csv', names=['passengers', 'value'])

# %%
df
# Out:
#    passengers    value
# 0           0      520
# 1           1  7726984
# 2           2  1561977
# 3           3   436431
# 4           4   210641
# 5           5   601079
# 6           6   369155
# 7           7       22
# 8           8       26
# 9           9       23

# %%
import plotly.express as px

# %%
fig = px.bar(df, x='passengers', y='value')
fig.show('png')

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Pie(labels=df.passengers, values=df.value)])

# %%
fig.show('png')
